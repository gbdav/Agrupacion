# %%
import pandas as pd

# %%
songs = pd.read_csv("source/SpotifyDailyTop200SongsWithGenres2017-2021/data.csv", sep="#")
songs
# Out:
#         Position                               Track Name            Artist  \
# 0              1                                  Starboy        The Weeknd
# 1              2                                   Closer  The Chainsmokers
# 2              3                          Let Me Love You          DJ Snake
# 3              4  Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit
# 4              5                                One Dance             Drake
# ...          ...                                      ...               ...
# 321195       196             Best Friend (feat. Doja Cat)          Saweetie
# 321196       197                  Wonderwall - Remastered             Oasis
# 321197       198                         MI FAI IMPAZZIRE            BLANCO
# 321198       199                                Adore You      Harry Styles
# 321199       200                               Follow You   Imagine Dragons
#
# ...

# %%
canPorArtista = songs.groupby(['Artist']).size().reset_index(name='canciones')
canPorArtista.sort_values(by='canciones',ascending=False).head(10)
# Out:
#                 Artist  canciones
# 289         Ed Sheeran       9461
# 817        Post Malone       9172
# 1078      XXXTENTACION       6569
# 116      Billie Eilish       6499
# 275              Drake       6496
# 62       Ariana Grande       5231
# 981   The Chainsmokers       4716
# 479         Juice WRLD       4593
# 1026      Travis Scott       4488
# 91           Bad Bunny       4042

# %%
repPorArtista = songs.groupby(['Artist'])['Streams'].sum().reset_index(name='reproducciones')
repPorArtista.sort_values(by='reproducciones',ascending=False).head(10)
# Out:
#              Artist  reproducciones
# 817     Post Malone     13513461417
# 289      Ed Sheeran     11450684279
# 275           Drake      9158708130
# 116   Billie Eilish      8570405790
# 62    Ariana Grande      8209907401
# 1078   XXXTENTACION      6759777399
# 91        Bad Bunny      6401130360
# 1001     The Weeknd      6078051362
# 279        Dua Lipa      5644638436
# 479      Juice WRLD      5448453625

# %%
songs.groupby(['Date'])['Streams'].sum().sort_values(ascending=False).head(10)
# Out:
# Date
# 2020-12-24    555245855
# 2020-12-25    499751288
# 2019-12-24    435039692
# 2018-12-24    388152254
# 2019-12-25    381091829
# 2020-12-11    369117102
# 2018-06-29    350167113
# 2020-01-17    349214437
# 2020-12-12    347377294
# 2018-12-25    347063373
# Name: Streams, dtype: int64
